# %%
import pandas as pd

# %%
# Import & read CSV file

csv_data = 'data.csv'


# Create dataframe based on CSV file

data = pd.read_csv(csv_data, encoding='latin1')

list(data.columns)
# Out:
# ['InvoiceNo',
#  'StockCode',
#  'Description',
#  'Quantity',
#  'InvoiceDate',
#  'UnitPrice',
#  'CustomerID',
#  'Country']

# %%
data.head(100)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ..       ...       ...                                  ...       ...
# 95    536378     22352    LUNCH BOX WITH CUTLERY RETROSPOT          6
# 96    536378     21212      PACK OF 72 RETROSPOT CAKE CASES       120
# 97    536378     21975       PACK OF 60 DINOSAUR CAKE CASES        24
# 98    536378     21977   PACK OF 60 PINK PAISLEY CAKE CASES        24
# 99    536378     84991          60 TEATIME FAIRY CAKE CASES        24
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# 0   12/1/2010 8:26       2.55     17850.0  United Kingdom
# ...

# %%
data['Date'] = pd.to_datetime(data['InvoiceDate'])

data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country                Date
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom 2010-12-01 08:26:00
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom 2010-12-01 08:26:00
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom 2010-12-01 08:26:00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom 2010-12-01 08:26:00
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom 2010-12-01 08:26:00

# %%
data['day'] = data.Date.dt.day

data['month'] = data.Date.dt.month

data['year'] = data.Date.dt.year

data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
data['ext_price'] = data['Quantity'] * data['UnitPrice']

data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-06dc1742c079> in <module>
# ----> 1 data = data.groupby('Country')
#       2 df = pd.DataFrame(data)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     578
#     579         raise AttributeError(
# --> 580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#     582
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'

# %%
# Out:
#                        0                                                  1
# 0              Australia         InvoiceNo StockCode                    ...
# 1                Austria         InvoiceNo StockCode                    ...
# 2                Bahrain         InvoiceNo StockCode                    ...
# 3                Belgium         InvoiceNo StockCode                    ...
# 4                 Brazil         InvoiceNo StockCode                    ...
# 5                 Canada         InvoiceNo StockCode                    ...
# 6        Channel Islands         InvoiceNo StockCode                    ...
# 7                 Cyprus         InvoiceNo StockCode                    ...
# 8         Czech Republic         InvoiceNo StockCode                    ...
# 9                Denmark         InvoiceNo StockCode                    ...
# 10                  EIRE         InvoiceNo StockCode                    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# Out:
#    rank country                                        description  \
# 0     0      US  This tremendous 100% varietal wine hails from ...
# 1     1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2     2      US  Mac Watson honors the memory of a wine once ma...
# 3     3      US  This spent 20 months in 30% new French oak, an...
# 4     4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#               variety                   winery
# 0  Cabernet Sauvignon                    Heitz
# ...

# %%
bins = [0, 84, 94, 100]

labels = ['good', 'great', 'best']

pd.cut(wine_df["points"], bins, labels=labels).head()
# Out:
# 0    best
# 1    best
# 2    best
# 3    best
# 4    best
# Name: points, dtype: category
# Categories (3, object): [good < great < best]

# %%
wine_df["quality"] = pd.cut(wine_df["points"], bins, labels=labels)
wine_df.tail()
# Out:
# C:\Users\alexr\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           rank country                                        description  \
# 150925  150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  150926  France  Offers an intriguing nose with ginger, lime an...
# 150927  150927   Italy  This classic example comes from a cru vineyard...
# 150928  150928  France  A perfect salmon shade, with scents of peaches...
# 150929  150929   Italy  More Pinot Grigios should taste like this. A r...
#
#             designation  points  price            province          variety  \
# ...

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   rank         150930 non-null  int64
#  1   country      150925 non-null  object
#  2   description  150930 non-null  object
#  3   designation  105195 non-null  object
#  4   points       150930 non-null  int64
#  5   price        137235 non-null  float64
#  6   province     150925 non-null  object
#  7   variety      150930 non-null  object
#  8   winery       150930 non-null  object
#  9   quality      150930 non-null  category
# dtypes: category(1), float64(1), int64(2), object(6)
# memory usage: 10.5+ MB

# %%
wine = wine_df.dropna()

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94919 entries, 0 to 150928
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         94919 non-null  int64
#  1   country      94919 non-null  object
#  2   description  94919 non-null  object
#  3   designation  94919 non-null  object
#  4   points       94919 non-null  int64
#  5   price        94919 non-null  float64
#  6   province     94919 non-null  object
#  7   variety      94919 non-null  object
#  8   winery       94919 non-null  object
#  9   quality      94919 non-null  category
# dtypes: category(1), float64(1), int64(2), object(6)
# memory usage: 7.3+ MB

# %%
wine.head()
# Out:
#    rank country                                        description  \
# 0     0      US  This tremendous 100% varietal wine hails from ...
# 1     1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2     2      US  Mac Watson honors the memory of a wine once ma...
# 3     3      US  This spent 20 months in 30% new French oak, an...
# 4     4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#               variety                   winery quality
# 0  Cabernet Sauvignon                    Heitz    best
# ...

# %%
# Export dataframe to csv

# wine.to_csv('cleaned_version.csv',index=False)

# %%
 from sklearn import tree

# %%
target = wine["designation"]
target_names = ["negative", "positive"]
